# %% [markdown]
# # Model Training & evaluation with Nvidia A100 SXM4 - 80
# ![A100-SXM4](https://tpucdn.com/gpu-specs/images/c/3746-front.jpg)

# %%
# Connect Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![A100-SXM4](https://img2.fr-trading.com/0/5_8_2834952_572_486.jpg.webp)

# %%
# !nvidia-smi
# Out:
# Mon Oct  6 15:42:42 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   35C    P0             55W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
! git clone https://github.com/KubilayBildirici/GPT-2-Tensorflow.git
# Out:
# Cloning into 'GPT-2-Tensorflow'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 82 (delta 26), reused 78 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (82/82), 459.50 KiB | 27.03 MiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %% [markdown]
# ## ✅ Fineweb data %100 Training

# %%
# !mkdir -p /content/drive/MyDrive/Fineweb_data

# %%
# !python /content/GPT-2-Tensorflow/data/fineweb_tf.py
# Out:
# 2025-10-06 15:47:17.089798: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-06 15:47:17.107359: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759765637.127624    4095 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759765637.133790    4095 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd /content/GPT-2-Tensorflow
# Out:
# /content/GPT-2-Tensorflow

# %%
# !ls
# Out:
# configs  gpt_train.py  optim	   __pycache__	requirements.txt
# data	 model.py      play.ipynb  README.md

# %%
import os
os.getcwd()
# Out:
# '/content/GPT-2-Tensorflow'

# %%
# !ls /content/GPT-2-Tensorflow/configs
# Out:
# config.py  gpt2_.json  __pycache__  training.yaml

# %%
# !python gpt_train.py
# Out:
# python3: can't open file '/content/gpt_train.py': [Errno 2] No such file or directory

# %%
import tensorflow as tf

from model import GPT
import keras

model = keras.models.load_model(
    "/content/GPT-2-Tensorflow/final_model.keras",
    custom_objects={"GPT": GPT}
)
print("✅ Model loaded successfully with custom class.")
# Out:
# ✅ Model loaded successfully with custom class.
